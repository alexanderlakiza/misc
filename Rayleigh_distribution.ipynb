# %%
import numpy as np
import math
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 5, 100)

# %%
sigma = 1

# %%
y = (x/sigma**2)*np.exp(-(x**2/2*sigma**2))

# %%
plt.plot(x, y)

# %%
sigma = 2
y = (x/sigma**2)*np.exp(-(x**2/2*sigma**2))
plt.plot(x, y)
